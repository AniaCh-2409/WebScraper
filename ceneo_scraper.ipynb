jEmv35Mzkt8/pBnEKioU5A==; __rtbh.lid=%7B%22eventType%22%3A%22lid%22%2C%22id%22%3A%22OkrMJG5sGvCHHh2aEFi9%22%2C%22expiryDate%22%3A%222027-03-12T11%3A17%3A14.530Z%22%7D; __rtbh.aid=%7B%22eventType%22%3A%22aid%22%2C%22id%22%3A%22eea295e4-1311-11f1-b20f-ac77d0636701%22%2C%22expiryDate%22%3A%222027-03-12T11%3A17%3A14.534Z%22%7D; __rtbh.uid=%7B%22eventType%22%3A%22uid%22%2C%22id%22%3A%22unknown%22%2C%22expiryDate%22%3A%222027-03-12T11%3A17%3A14.542Z%22%7D; ga4_ga_K2N2M0CBQ6=GS2.2.s1773314200$o1$g1$t1773314243$j51$l0$h705029139; ttcsid_CNK74OBC77U1PP7E4UR0=1773314215885::OGUyRqRVZuDiu1eTx-Zw.1.1773314243446.1; ttcsid=1773314215886::-Mxcoy8Z1vRdXKA8wL9n.1.1773314243446.0::1.27465.18829::0.0.0.0::306372.7.0",
           "User-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/146.0.0.0 Safari/537.36",
           "Host": "www.ceneo.pl"
}

# %%
url = "https://www.ceneo.pl/124893467#tab=reviews"
response = requests.get(url)
print(response.status_code)
# Out:
# 200

# %% [markdown]
# ### Parsowanie strony z opiniami

# %%
page_dom = BeautifulSoup(response.text, 'html.parser')
print(type(page_dom))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
opinions = page_dom.select("div.js_product-review:not(.user-post--highlight)")
print(type(opinions))
print(len(opinions))
# Out:
# <class 'bs4.element.ResultSet'>
# 10

# %%
opinion = page_dom.select_one("div.js_product-review")
print(type(opinion))
# Out:
# <class 'bs4.element.Tag'>

# %%
opinion = opinions.pop(0)
print(type(opinion))
# Out:
# <class 'bs4.element.Tag'>

# %% [markdown]
# ### Analiza struktury pojedynczej opinii

# %% [markdown]
# |skladowa|nazwa|selektor|
# |--------|-----|--------|
# |opinia|opinion|div.js_product-review|
# |identyfikator|opinion_id|[data-entry-id]|
# |autor|author|span.user-post__author-name|
# |treść|content|div.user-post__text|
# |ocena|score|span.user-post__score-count|
# |rekomendacja|recommendation|span.user-post__author-recomendation > em|
# |lista zalet|pros|div.review-feature__item--positive|
# |lista wad|cons|div.review-feature__item--negative|
# |dla ilu przydatna|thumbs_up|button.vote-yes > span|
# |dla ilu nieprzydatna|thumbs_down|button.vote-no > span|
# |data zamieszczenia|post_date|span.user-post__published > time:nth-child(1)[datetime]|
# |data zakupu|purchase_date|span.user-post__published > time:nth-child(2)[datetime]|

# %%
all_opinions = []
for opinion in opinions:
    opinion_data = {}
    
    # identyfikator opinii
    opinion_data["opinion_id"] = opinion.get("data-entry-id")
    
    # Autor
    opinion_data["author"] = opinion.select_one("span.user-post__author-name").get_text(strip = True)
    
    # Treść opinii
    opinion_data["content"] = opinion.select_one("div.user-post__text").get_text(strip = True)

    # Ocena
    opinion_data["score"] = opinion.select_one(".user-post__score-count").get_text(strip = True)
    opinion_data["score"] = float(opinion_data["score"].split("/")[0].replace(",","."))

    # Rekomendacja (Polecam/Nie polecam)
    try:
        opinion_data["recommendation"] = opinion.select_one("span.user-post__author-recomendation > em").get_text(strip = True)
    except AttributeError:
        opinion_data["recommendation"] = None
    
    # Lista zalet
    opinion_data["pros"] = [p.get_text(strip = True) for p in opinion.select("div.review-feature__item--positive")]
    
    # Lista wad
    opinion_data["cons"] = [c.get_text(strip = True) for c in opinion.select("div.review-feature__item--negative")]

    # Dla ilu osób przydatna
    opinion_data["useful"] = int(opinion.select_one("button.vote-yes > span").get_text(strip = True))
    
    # Dla ilu osób nieprzydatna
    opinion_data["unuseful"] = int(opinion.select_one("button.vote-no > span").get_text(strip = True))
    
    # Data zamieszczenia
    opinion_data["post_date"] = opinion.select_one("span.user-post__published > time:nth-child(1)").get("datetime")
    
    # Data zakupu / potwierdzony zakup
    try:
        opinion_data["purchase_date"] = opinion.select_one("span.user-post__published > time:nth-child(2)").get("datetime")
    except AttributeError:
        opinion_data["purchase_date"]
        
    all_opinions.append(opinion_data)
    
# Wyświetlenie zebranych opinii
for single_opinion in all_opinions:
    print(single_opinion)
# Out:
# {'opinion_id': '19466347', 'author': 'Tomasz', 'content': 'To moja pierwsza drukarka atramentowa od lat. Łatwość instalacji wg instrukcji i jakość druku dokumentów obłędne! Jestem zachwycony jakością. Bardzo wygodne drukowanie z dowolnego miejsca i urządzenia po podłączeniu do konta HP Smart. Dokładnie to, czego oczekiwałem. Pełne zadowolenie.', 'score': 5.0, 'recommendation': 'Polecam', 'pros': ['czyste napełnianie atramentem', 'jakość wydruków', 'niski koszt wydruku', 'szybkość wydruku', 'wydajna', 'wydajność'], 'cons': [], 'useful': 0, 'unuseful': 0, 'post_date': '2025-02-21 10:04:13', 'purchase_date': '2025-02-05 14:16:00'}
# {'opinion_id': '17905905', 'author': 'p...k', 'content': 'Drukarka fajna, super uzupełnianie tuszu, tusze w zestawie. Ogólnie dał bym 5 gwiazdek ale. No właśnie to ale, głowice załączone z drukarką wyświetlały cały czas błąd przez co nie dało się zakończyć procesu rejestracji. Kolorowa zgasła dopiero na drugi dzień a z czarną nie obyło się bez serwisu. Efekt taki że nie można było korzystać z drukarki przez 4 dni.', 'score': 3.0, 'recommendation': None, 'pros': ['czyste napełnianie atramentem', 'głośność pracy', 'jakość wydruków', 'jakość wydruku', 'niski koszt wydruku', 'wydajna', 'wydajność'], 'cons': ['czas wyłączenia 2h', 'szybkość wydruku'], 'useful': 1, 'unuseful': 0, 'post_date': '2023-09-15 11:36:42', 'purchase_date': '2023-09-10 12:31:48'}
# {'opinion_id': '19868086', 'author': 'Użytkownik Ceneo', 'content': 'Droga w zakupie, ale za to tanie tusze. Dość szybka, ładne kolory, skaner trochę wolny. Instalacja bez problemu. Dużym atutem jest wymienna głowica drukująca', 'score': 5.0, 'recommendation': 'Polecam', 'pros': ['jakość wydruków', 'szybkość wydruku', 'wydajna', 'wydajność'], 'cons': [], 'useful': 0, 'unuseful': 0, 'post_date': '2025-08-20 12:08:52', 'purchase_date': '2025-08-02 18:24:36'}
# {'opinion_id': '20328239', 'author': 'krystynaperek*****', 'content': 'Drukarka bardzo dobra działa super, ale miałam problem z jej zainstalowaniem raczej z jej konfiguracją z laptopem ale jest ok.', 'score': 4.5, 'recommendation': 'Polecam', 'pros': [], 'cons': [], 'useful': 0, 'unuseful': 0, 'post_date': '2026-02-24 12:38:58', 'purchase_date': '2026-02-04 12:15:39'}
# {'opinion_id': '18035211', 'author': 'k...i', 'content': 'drukuje cicho i szybko, ma możliwość druku dwustronnego działa dobrze', 'score': 5.0, 'recommendation': 'Polecam', 'pros': ['czyste napełnianie atramentem', 'głośność pracy', 'jakość wydruków', 'szybkość wydruku', 'wydajna'], 'cons': [], 'useful': 0, 'unuseful': 0, 'post_date': '2023-10-25 10:28:48', 'purchase_date': '2023-10-16 18:38:31'}
# {'opinion_id': '17671771', 'author': 'Tomasz', 'content': 'Dobra jakość wydruku, tanie tusze, dobra współpraca z Android i Apple', 'score': 5.0, 'recommendation': 'Polecam', 'pros': ['jakość wydruków', 'jakość wydruku', 'szybkość wydruku', 'wydajność'], 'cons': [], 'useful': 0, 'unuseful': 0, 'post_date': '2023-07-03 22:28:41', 'purchase_date': '2023-06-12 11:39:26'}
# {'opinion_id': '19533453', 'author': 's...s', 'content': 'Ciężko powiedziećz uwagi na zbyt krótki okres użytkowania', 'score': 5.0, 'recommendation': 'Polecam', 'pros': ['jakość wydruków', 'szybkość wydruku', 'wydajna', 'wydajność'], 'cons': [], 'useful': 0, 'unuseful': 0, 'post_date': '2025-03-19 08:38:06', 'purchase_date': '2025-03-02 22:01:32'}
# {'opinion_id': '17554471', 'author': 'j...7', 'content': 'Jak na razie rewelacja. Wspaniała jakość wydruku. Szybka.', 'score': 5.0, 'recommendation': 'Polecam', 'pros': [], 'cons': [], 'useful': 0, 'unuseful': 0, 'post_date': '2023-05-27 06:48:00', 'purchase_date': '2023-05-18 15:00:35'}
# {'opinion_id': '17486388', 'author': 'r...8', 'content': 'Drukarka bardzo dobra, może trochę dużych rozmiarów.', 'score': 4.5, 'recommendation': 'Polecam', 'pros': ['czyste napełnianie atramentem', 'głośność pracy', 'jakość wydruków', 'jakość wydruku', 'niski koszt wydruku', 'szybkość wydruku', 'wydajna', 'wydajność'], 'cons': [], 'useful': 0, 'unuseful': 0, 'post_date': '2023-05-08 23:57:47', 'purchase_date': '2023-04-22 13:30:38'}

# %%
page = 1
next = True
while next:
    url = f"https://www.ceneo.pl/124893467/opinie-{page}"
    response = requests.get(url, headers = headers)
    page_dom = BeautifulSoup(response.text, 'html.parser')
    opinions = page_dom.select("div.js_product-review:not(.user-post--highlight)")
    print(f"{url} => {response.status_code} => {len(opinions)}")
    next = True if page_dom.select_one("button.pagination__next") else False
    page += 1
# Out:
# https://www.ceneo.pl/124893467/opinie-1 => 200 => 10
# https://www.ceneo.pl/124893467/opinie-2 => 200 => 0
