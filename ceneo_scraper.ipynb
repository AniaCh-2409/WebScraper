# %% [markdown]
# ## Import bibliotek

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Pobranie z serwisu [Ceneo.pl](https://ceneo.pl/) opinii o wybranym produkcie

# %% [markdown]
# Potencjalne produkty
# - 124893467
# - 106545192
# - 32918774
# - 83177636
# - 91869341

# %% [markdown]
# ### Wysłanie żądania dostępu do zasobu (strony WWW)

# %%
headers = {"Cookie": "sv3=1.0_eea295e4-1311-11f1-b20f-ac77d0636701; userCeneo=ID=c31f28fc-28cd-40e0-92cd-a6d3ea3d3f72; ai_user=DykIE|2026-02-26T12:51:56.819Z; appType=%7B%22Value%22%3A1%7D; urdsc=1; __RequestVerificationToken=m3BujWUiW7gDdx3IAGA26fXod5u4FR1HYn6Aw1zRqxedqqzBNVc9kEDvZnaGLUmk53d2CmUm3AiFPVnuZfbWqew-vMfRWf7BN1fjC-jrEAg1; __utmf=9a00c24957ce44da5dfa82e56ac8c543_k2wCRI6tAVSgxOOwMsWh%2Bvo35Yf981ST; cProdCompare_v2=; browserBlStatus=0; ga4_ga=GA1.2.eea295e4-1311-11f1-b20f-ac77d0636701; _gcl_au=1.1.145062677.1773314206; consentcookie=...; FPID=FPID2.2.7P6%2FkYZywyIC5f5%2FtIuhbwP%2BcI2%2BPtt%2FlVaosd7YN30%3D; fs=et%3d639089152096088232%26sg%3dc30ef342-dca7-4618-a0a6-1ea26bfeeb46%26st%3d124893467%26encode%3dtrue; _fbp=fb.1.1773314214990.885254430717221419; __gads=ID=6cef3570335a704c:T=1773314210:RT=1773314210:S=ALNI_MY3deJp3Bao61TIJ4rpNKW3eTTcdg; __gpi=UID=0000134cc713523f:T=1773314210:RT=1773314210:S=ALNI_MZGBGar7yS4Bs2SCCAtLQSpqb866A; __eoi=ID=3602aabfcf2145bc:T=1773314210:RT=1773314210:S=AA-AfjbcKKbC_U78G4B8O28MDcbZ; cto_bundle=vdb3tV9LWG42TmtTM01rVGJUMmI4d1BOdzFNVVp5MlFpMyUyRjluWEhFejNudUJiRVZJOSUyQjlXbmRuMzAxR1lja1hoVjhyZUcyNkJJRFdRbHZLUndaRERscFBpSkZLRGRvdGxBTiUyRnlybGN2QVhUNmlkaDl6NVdVUzh1bmJaWmQwS2s2VnpsdjhadGdaSXJXNnIlMkJUNE9PaWFORXp1QSUzRCUzRA; _tt_enable_cookie=1; _ttp=01KKGW73YAGHW5GP68PBC01D8D_.tt.1; FPLC=9FoXlfZHetit5rAOTGXHhG7aZ6Gy9RuLtI2xKgFgZVQTxbNUlnk%2BgsA8CI593CnvcPj%2BBuTShB%2FK4Vv3pF%2F8Rop5Qm1xiiGut1%2BXcfkH%2BbJblpw%3D; rc=igdamb4ThOT/AObseYIgrEpeFsMflKvyVUKo2f+MS98s4jqqOJAICB2yOpMY+WouFXVHKyA/uA1KXhbDH5Sr8lVCqNn/jEvfLOI6qjiQCAhdyohHP2qmvzlUuFz5so38sU7M1f3JAT4Nn76TZdd+gEwbOrrxyEEFsOBTViUmHM9tt47UAq9qs5NO72UYER19jEmv35Mzkt8/pBnEKioU5A==; __rtbh.lid=%7B%22eventType%22%3A%22lid%22%2C%22id%22%3A%22OkrMJG5sGvCHHh2aEFi9%22%2C%22expiryDate%22%3A%222027-03-12T11%3A17%3A14.530Z%22%7D; __rtbh.aid=%7B%22eventType%22%3A%22aid%22%2C%22id%22%3A%22eea295e4-1311-11f1-b20f-ac77d0636701%22%2C%22expiryDate%22%3A%222027-03-12T11%3A17%3A14.534Z%22%7D; __rtbh.uid=%7B%22eventType%22%3A%22uid%22%2C%22id%22%3A%22unknown%22%2C%22expiryDate%22%3A%222027-03-12T11%3A17%3A14.542Z%22%7D; ga4_ga_K2N2M0CBQ6=GS2.2.s1773314200$o1$g1$t1773314243$j51$l0$h705029139; ttcsid_CNK74OBC77U1PP7E4UR0=1773314215885::OGUyRqRVZuDiu1eTx-Zw.1.1773314243446.1; ttcsid=1773314215886::-Mxcoy8Z1vRdXKA8wL9n.1.1773314243446.0::1.27465.18829::0.0.0.0::306372.7.0",
           "User-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/146.0.0.0 Safari/537.36",
           "Host": "www.ceneo.pl"
}

# %%
url = "https://www.ceneo.pl/124893467#tab=reviews"
response = requests.get(url)
print(response.status_code)

# %%
page_dom = BeautifulSoup(response.text, 'html.parser')

# %%
opinions = page_dom.select("div.js_product-review:not(.user-post--highlight)")
print(type(opinions))
print(len(opinions))

# %%
opinion = page_dom.select_one("div.js_product-review")
print(type(opinion))

# %%
opinion = opinions.pop(0)
print(type(opinion))
